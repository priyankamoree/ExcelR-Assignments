# %%
import pandas as pd
import numpy as np
from scipy.stats import norm,t
from sklearn.impute import SimpleImputer
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\priya\Downloads\EDA1\EDA1\Cardiotocographic.csv")
pd.set_option('display.precision',6)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
#  * Here columns **LB, AC, DS, DP, MLTV, Width, Tendency &  NSP** has missing values since there count is less than the total number of rows in given data

# %%
si = SimpleImputer(strategy='median')

# %%
df.iloc[:,[0,1,5,6,10,11,12,13]]= si.fit_transform(df.iloc[:,[0,1,5,6,10,11,12,13]])

# %%
df.isna().sum()                                                     #To check if we have any missing values in our data
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# - **Statistical sumarry**
# - Here describe function calculates the mean, median, standard deviation, min, max and quantile values for each columns along with thier total value count

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.dtypes                                           #No inconsisties in data types in given data
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.boxplot()                  #Almost every column has outliers
# Out:
# <Axes: >

# %%
df.hist()
plt.tight_layout()

# %%
#Replacing the outlier values with the Min and Max values of that respective columns 
def outlier_detection(data, cols):
    
    for col in cols:
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        iqr = q3-q1
    
        lower = q1-(1.5*iqr)
        upper = q3+(1.5*iqr)
        
        df[col] = np.where(df[col] > upper, upper, np.where(df[col] < lower, lower,df[col]))

# %%
outlier_detection(df,df.columns)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.006416  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 0      0.5  27.5   2.4   64.0  0.999926  1.0
# ...

# %%
df.boxplot()
plt.tight_layout()

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.290331     0.003132     0.001568     0.004362     0.001770
# std       9.930268     0.003828     0.002485     0.003001     0.002668
# min     105.000000    -0.008409    -0.003850    -0.005177    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     161.000000     0.014015     0.006416     0.013564     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2126.0  2126.0  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.0     0.0    46.981873     1.304644     6.691678     8.007471
# std       0.0     0.0    17.612745     0.781091    10.378400     5.047078
# ...

# %% [markdown]
# The above data now **doesn't contain outlier values, missing values or null values.**

# %%
#To find the Correlation between the columns across our data we are goint to plot scatter plot 
sns.pairplot(df)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis',annot_kws={"size": 12})
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080759 -0.006929 -0.162811 -0.156260 NaN NaN  0.285623
# AC       -0.080759  1.000000  0.075669  0.093614 -0.103048 NaN NaN -0.272452
# FM       -0.006929  0.075669  1.000000 -0.317265 -0.017610 NaN NaN  0.156351
# UC       -0.162811  0.093614 -0.317265  1.000000  0.268605 NaN NaN -0.215984
# DL       -0.156260 -0.103048 -0.017610  0.268605  1.000000 NaN NaN -0.111624
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285623 -0.272452  0.156351 -0.215984 -0.111624 NaN NaN  1.000000
# MSTV     -0.295600  0.216377  0.070300  0.297843  0.566340 NaN NaN -0.433844
# ALTV      0.322431 -0.408012 -0.013420 -0.293340 -0.295886 NaN NaN  0.439040
# MLTV     -0.042578 -0.152012 -0.037001 -0.074192 -0.242728 NaN NaN -0.324702
# ...

# %% [markdown]
# * **I don't see a strong correlation between any of the above columns. It mostly have Weak to Moderate correlation and for that we don't have to worry about.**
# * **While the columns DS, DP and NSP has only same type of value (i.e no variance in a column) so we can delete these two columns for better insights from our model as well as data.**
# * **Also, having no variance means no contribution to a model building part.**

# %%
df= df.drop(columns=['DS','DP','NSP'])

# %%
df
# Out:
#               LB        AC        FM        UC        DL  ASTV  MSTV  ALTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  73.0   0.5  27.5
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  17.0   2.1   0.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  16.0   2.1   0.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  16.0   2.4   0.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  16.0   2.4   0.0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 2121  140.000000  0.000000  0.006416  0.007426  0.000000  79.0   0.2  25.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  78.0   0.4  22.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  79.0   0.4  20.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  78.0   0.4  27.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  74.0   0.4  27.5
#
#       MLTV  Width  Tendency
# 0      2.4   64.0  0.999926
# ...
